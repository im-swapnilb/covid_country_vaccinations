# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(color_codes = True)

# %%
data = pd.read_csv('country_vaccinations.csv')
data.head(200)
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 0    Albania      ALB  2021-01-10                 0.0                0.0
# 1    Albania      ALB  2021-01-11                 NaN                NaN
# 2    Albania      ALB  2021-01-12               128.0              128.0
# 3    Albania      ALB  2021-01-13               188.0              188.0
# 4    Albania      ALB  2021-01-14               266.0              266.0
# ..       ...      ...         ...                 ...                ...
# 195  Austria      AUT  2021-02-08            298195.0           212062.0
# 196  Austria      AUT  2021-02-09            311221.0           215592.0
# 197  Austria      AUT  2021-02-10            329881.0           219286.0
# 198  Austria      AUT  2021-02-11            343069.0           224467.0
# 199  Austria      AUT  2021-02-12            365414.0           229317.0
#
#      people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
#Dataframe column characteristics
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4043 entries, 0 to 4042
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              4043 non-null   object
#  1   iso_code                             3755 non-null   object
#  2   date                                 4043 non-null   object
#  3   total_vaccinations                   2647 non-null   float64
#  4   people_vaccinated                    2237 non-null   float64
#  5   people_fully_vaccinated              1481 non-null   float64
#  6   daily_vaccinations_raw               2237 non-null   float64
#  7   daily_vaccinations                   3896 non-null   float64
#  8   total_vaccinations_per_hundred       2647 non-null   float64
#  9   people_vaccinated_per_hundred        2237 non-null   float64
#  10  people_fully_vaccinated_per_hundred  1481 non-null   float64
# ...

# %%
data.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        2.647000e+03       2.237000e+03             1.481000e+03
# mean         1.583567e+06       1.384480e+06             4.308568e+05
# std          5.322104e+06       4.350214e+06             1.649615e+06
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          3.060900e+04       2.846600e+04             9.844000e+03
# 50%          1.917900e+05       1.769260e+05             4.402100e+04
# 75%          7.784380e+05       6.761860e+05             2.236090e+05
# max          6.503208e+07       4.454497e+07             1.988254e+07
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            2.237000e+03        3.896000e+03
# mean             7.215689e+04        5.552814e+04
# std              2.028147e+05        1.746934e+05
# min             -5.001200e+04        1.000000e+00
# 25%              2.048000e+03        1.129000e+03
# ...

# %%
#total no of rows and columns in the dataframe
data.shape
# Out:
# (4043, 15)

# %%
#Displaying the empty cells list in the data 
data.isnull().sum()
# Out:
# country                                   0
# iso_code                                288
# date                                      0
# total_vaccinations                     1396
# people_vaccinated                      1806
# people_fully_vaccinated                2562
# daily_vaccinations_raw                 1806
# daily_vaccinations                      147
# total_vaccinations_per_hundred         1396
# people_vaccinated_per_hundred          1806
# people_fully_vaccinated_per_hundred    2562
# daily_vaccinations_per_million          147
# vaccines                                  0
# source_name                               0
# source_website                            0
# dtype: int64

# %%
#Displaying list of the numerous countries in the dataset
data["country"].unique()
# Out:
# array(['Albania', 'Algeria', 'Andorra', 'Anguilla', 'Argentina',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Bermuda', 'Bolivia', 'Brazil',
#        'Bulgaria', 'Cambodia', 'Canada', 'Cayman Islands', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Croatia', 'Cyprus', 'Czechia',
#        'Denmark', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
#        'England', 'Estonia', 'Faeroe Islands', 'Falkland Islands',
#        'Finland', 'France', 'Germany', 'Gibraltar', 'Greece', 'Greenland',
#        'Guernsey', 'Guyana', 'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Iran', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Japan',
#        'Jersey', 'Kuwait', 'Latvia', 'Lebanon', 'Liechtenstein',
#        'Lithuania', 'Luxembourg', 'Macao', 'Maldives', 'Malta',
#        'Mauritius', 'Mexico', 'Monaco', 'Morocco', 'Myanmar', 'Nepal',
#        'Netherlands', 'New Zealand', 'Northern Cyprus',
# ...

# %%
#All different names of the vaccines
data['vaccines'].unique()
# Out:
# array(['Pfizer/BioNTech', 'Sputnik V', 'Oxford/AstraZeneca',
#        'Moderna, Oxford/AstraZeneca, Pfizer/BioNTech',
#        'Oxford/AstraZeneca, Sputnik V',
#        'Pfizer/BioNTech, Sinopharm/Beijing',
#        'Oxford/AstraZeneca, Sinovac', 'Sinopharm/Beijing',
#        'Moderna, Pfizer/BioNTech', 'Pfizer/BioNTech, Sinovac',
#        'Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac',
#        'Oxford/AstraZeneca, Pfizer/BioNTech',
#        'Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V',
#        'Covaxin, Oxford/AstraZeneca', 'Sinovac',
#        'Oxford/AstraZeneca, Sinopharm/Beijing',
#        'Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V',
#        'Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V', 'Johnson&Johnson',
#        'Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V'],
#       dtype=object)

# %%
#length of the number of countries
len(data['country'].unique())
# Out:
# 105

# %%
# total number of vaccines/vaccine combinations
len(data['vaccines'].unique())
# Out:
# 20

# %%
sns.boxplot(data['people_vaccinated'][50:100])
# Out:
# C:\Users\sbandgar\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(data['country'][40:200], data['total_vaccinations'][0:100])

# %%
dates = data['date'].values[10:10]
vaccines = data['vaccines'].values[10:10]
plt.bar(dates,vaccines)
plt.xlabel('dates')
plt.ylabel('vaccines')
plt.title('All Countries data')
plt.xticks(rotation = 100)
plt.show()

# %%
#Daily Vaccination Rate Comparision
fig = go.Figure()
md1 = data[data['country']=='United States']
md2 = data[data['country']=='United Kingdom']
md3 = data[data['country']=='Canada']
fig.add_trace(go.Scatter(x=md1.date,y=md1.daily_vaccinations,mode='lines+markers',name='US'))
fig.add_trace(go.Scatter(x=md2.date,y=md2.daily_vaccinations,mode='lines+markers',line=dict(color='firebrick',width=2),name='UK'))
fig.add_trace(go.Scatter(x=md3.date,y=md3.daily_vaccinations,mode='lines+markers',line=dict(dash='dashdot'),name='Canada'))

fig.update_layout(title = 'Daily Vaccination Rate Comparision in the US, UK & Canada',xaxis_title='Date',yaxis_title='Daily Vaccination' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-fe480162e637> in <module>
#       1 #Daily Vaccination Rate Comparision
# ----> 2 fig = go.Figure()
#       3 md1 = data[data['country']=='United States']
#       4 md2 = data[data['country']=='United Kingdom']
#       5 md3 = data[data['country']=='Canada']
#
# NameError: name 'go' is not defined

# %%
sns.distplot(data['daily_vaccinations'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-f7df1fbc741a> in <module>
# ----> 1 sns.distplot(data['daily_vaccinations'])
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      37         return int(np.sqrt(a.size))
#      38     else:
# ---> 39         return int(np.ceil((a.max() - a.min()) / h))
#      40
#      41
#
# ValueError: cannot convert float NaN to integer

# %%
#Daily vaccination rate in the US
sns.scatterplot(data[data['country']=='United States'],x='date',y='daily_vaccinations').update_layout(title = 'Daily Vaccination Rate in the US',xaxis_title='Date',yaxis_title='Daily Vaccination' )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-ed6ef192b7c9> in <module>
#       1 #Daily vaccination rate in the US
# ----> 2 sns.scatterplot(data[data['country']=='United States'],x='date',y='daily_vaccinations').update_layout(title = 'Daily Vaccination Rate in the US',xaxis_title='Date',yaxis_title='Daily Vaccination' )
#
# TypeError: scatterplot() got multiple values for argument 'x'

# %%
#Number of countries using different vaccine types/combinations
data.groupby(['country'],sort=False, as_index=False)['vaccines'].first()
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.set(style = 'whitegrid')
sns.countplot(x="vaccines", data=data.groupby(['country'],sort=False, as_index=False)['vaccines'].first())
plt.title("Countries using Different Vaccines Types\n",size =20)
plt.ylabel("No of Countries",size=15)
plt.xlabel("\nVaccine Types\n\n",size=15)
# Out:
# Text(0.5, 0, '\nVaccine Types\n\n')

# %%
#Finding Maximum number of people vaccinated in each country
vaccine = data.groupby(["country","vaccines"])['total_vaccinations','total_vaccinations_per_hundred',
                                       'daily_vaccinations','daily_vaccinations_per_million'].max().reset_index()
vaccine
# Out:
#                       country  \
# 0                     Albania
# 1                     Algeria
# 2                     Andorra
# 3                    Anguilla
# 4                   Argentina
# 5                   Australia
# 6                     Austria
# 7                  Azerbaijan
# 8                     Bahrain
# 9                  Bangladesh
# 10                   Barbados
# 11                    Belarus
# 12                    Belgium
# 13                    Bermuda
# 14                    Bolivia
# 15                     Brazil
# 16                   Bulgaria
# 17                   Cambodia
# 18                     Canada
# 19             Cayman Islands
# 20                      Chile
# 21                      China
# 22                   Colombia
# 23                 Costa Rica
# 24                    Croatia
# 25                     Cyprus
# 26                    Czechia
# 27                    Denmark
# 28         Dominican Republic
# 29                    Ecuador
# ...

# %%
#Showing Total Vaccinated in TreeMap
import plotly.express as px

fig = px.treemap(vaccine,path = ['vaccines','country'],values='total_vaccinations')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-42-e218964e7579> in <module>
#       1 #Showing Total Vaccinated in TreeMap
# ----> 2 import plotly.express as px
#       3
#       4 fig = px.treemap(vaccine,path = ['vaccines','country'],values='total_vaccinations')
#       5 fig.show()
#
# ModuleNotFoundError: No module named 'plotly'
